# %%
# !pip install osmnx
# !pip install contextily
# Out:
# Collecting osmnx
#   Downloading osmnx-1.9.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting geopandas<0.15,>=0.12 (from osmnx)
#   Downloading geopandas-0.14.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: networkx<3.4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from osmnx) (3.3)
# Requirement already satisfied: numpy<1.27,>=1.20 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.26.4)
# Requirement already satisfied: pandas<2.3,>=1.1 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.1.4)
# Requirement already satisfied: requests<2.33,>=2.27 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.32.3)
# Requirement already satisfied: shapely<2.1,>=2.0 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.0.6)
# Collecting fiona>=1.8.21 (from geopandas<0.15,>=0.12->osmnx)
#   Downloading fiona-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 629.8 kB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas<0.15,>=0.12->osmnx) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas<0.15,>=0.12->osmnx) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3,>=1.1->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3,>=1.1->osmnx) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.3,>=1.1->osmnx) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<2.33,>=2.27->osmnx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<2.33,>=2.27->osmnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<2.33,>=2.27->osmnx) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<2.33,>=2.27->osmnx) (2024.8.30)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (24.2.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx) (8.1.7)
# Collecting click-plugins>=1.0 (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.21->geopandas<0.15,>=0.12->osmnx)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<2.3,>=1.1->osmnx) (1.16.0)
# Downloading osmnx-1.9.4-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 1.6 MB/s eta 0:00:00
# Downloading geopandas-0.14.4-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.9 MB/s eta 0:00:00
# Downloading fiona-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 46.1 MB/s eta 0:00:00
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Installing collected packages: cligj, click-plugins, fiona, geopandas, osmnx
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 1.0.1
#     Uninstalling geopandas-1.0.1:
#       Successfully uninstalled geopandas-1.0.1
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.10.1 geopandas-0.14.4 osmnx-1.9.4
# Collecting contextily
#   Downloading contextily-1.6.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from contextily) (3.7.1)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from contextily) (10.4.0)
# Collecting rasterio (from contextily)
#   Downloading rasterio-1.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from contextily) (2.32.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from contextily) (1.4.2)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from contextily) (2024.9.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.10/dist-packages (from mercantile->contextily) (8.1.7)
# Collecting affine (from rasterio->contextily)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (24.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (2024.8.30)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (2.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Downloading contextily-1.6.2-py3-none-any.whl (17 kB)
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading rasterio-1.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 42.5 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: mercantile, affine, rasterio, contextily
# Successfully installed affine-2.4.0 contextily-1.6.2 mercantile-1.2.1 rasterio-1.4.0

# %%
import osmnx as ox
ox.plot_graph(ox.graph_from_place('Espartinas, Spain'))
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
Huelva = "Huelva, Spain"
graph = ox.graph_from_place(Huelva)

# %%
nodes, edges = osmnx.graph_to_gdfs(graph)
edges.plot()
# Out:
# <Axes: >

# %%
G = ox.graph_from_address('Estacion Biologica de Doñana, Sevilla', network_type='drive')
ox.plot_graph(G)
# Out:
# /usr/local/lib/python3.10/dist-packages/osmnx/graph.py:191: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   G = graph_from_bbox(
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
G = ox.graph_from_place('Huelva', network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
buildings = ox.geometries_from_place(
    Huelva,
    {"building": True},
)
# Out:
# <ipython-input-9-b948b5b96352>:1: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   buildings = ox.geometries_from_place(

# %%
buildings.head()
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
#                                           geometry addr:city addr:housenumber  \
# element_type osmid
# node         1542062287  POINT (-6.95245 37.25614)       NaN              NaN
#              4991109060  POINT (-6.95503 37.25656)       NaN              NaN
#              5808932168  POINT (-6.94935 37.24168)    Huelva               21
#              7997720516  POINT (-6.94872 37.25905)       NaN              NaN
#              8090578692  POINT (-7.00034 37.25509)       NaN              NaN
#
#                         addr:postcode           addr:street    amenity  fee  \
# element_type osmid
# node         1542062287           NaN                   NaN        NaN  NaN
#              4991109060           NaN                   NaN     clinic  NaN
#              5808932168         21005  Calle Joaquín Turina  recycling  NaN
#              7997720516           NaN                   NaN    parking  NaN
#              8090578692           NaN                   NaN        NaN  NaN
#
#                                                                       name  \
# element_type osmid
# node         1542062287  Inspección Provincial de Trabajo y Seguridad S...
#              4991109060  Delegación Provincial de Turismo, Comercio y D...
#              5808932168                             Punto limpio de Huelva
#              7997720516                                                NaN
#              8090578692                                           La Choza
#
#                         building       government  ...  \
# element_type osmid                                 ...
# node         1542062287      yes  social_security  ...
#              4991109060    civic              NaN  ...
#              5808932168      yes              NaN  ...
#              7997720516      yes              NaN  ...
#              8090578692      yes              NaN  ...
#
#                         seamark:light:reference  \
# element_type osmid
# node         1542062287                     NaN
#              4991109060                     NaN
#              5808932168                     NaN
#              7997720516                     NaN
#              8090578692                     NaN
#
#                         seamark:radar_transponder:category  \
# element_type osmid
# node         1542062287                                NaN
#              4991109060                                NaN
#              5808932168                                NaN
#              7997720516                                NaN
#              8090578692                                NaN
#
#                         seamark:radar_transponder:group  \
# element_type osmid
# node         1542062287                             NaN
#              4991109060                             NaN
#              5808932168                             NaN
#              7997720516                             NaN
#              8090578692                             NaN
#
#                         seamark:radar_transponder:period seamark:type ways  \
# element_type osmid
# node         1542062287                              NaN          NaN  NaN
#              4991109060                              NaN          NaN  NaN
#              5808932168                              NaN          NaN  NaN
#              7997720516                              NaN          NaN  NaN
#              8090578692                              NaN          NaN  NaN
#
#                          bus public_transport type operator:website
# element_type osmid
# node         1542062287  NaN              NaN  NaN              NaN
#              4991109060  NaN              NaN  NaN              NaN
#              5808932168  NaN              NaN  NaN              NaN
#              7997720516  NaN              NaN  NaN              NaN
#              8090578692  NaN              NaN  NaN              NaN
#
# [5 rows x 118 columns]

# %% [markdown]
# Hacemos la distancia en wgs y en etrs

# %%
buildings_etrs = buildings.to_crs('EPSG:32629')

# %%
buildings_etrs['geometry'][0].distance(buildings_etrs['geometry'][1])
# Out:
# /usr/local/lib/python3.10/dist-packages/geopandas/geoseries.py:648: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   val = getattr(super(), mtd)(*args, **kwargs)
# 233.1699690888115

# %%
restaurants = ox.geometries_from_place(
    "Huelva",
    {
        "amenity": "restaurant"
    }
)
len(restaurants)
# Out:
# <ipython-input-14-e3620d3b80ec>:1: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   restaurants = ox.geometries_from_place(
# 71

# %%
for i in restaurants['name']:
  print(i)
# Out:
# Pomodoro
# Bar Restaurante La Higuerita
# Bar Restaurante Palomeque
# Mesón Madrid
# nan
# nan
# nan
# Cerveceria Bonilla
# Restaurante la Marina del Puerto
# Rocataliata
# El Tostón
# Club Náutico
# nan
# Casa Manguara
# La Higuerita Bar Restaurante
# Rey del Pollo Asado
# Asador Pida Pollo
# Churrasqueria Pio Pio (Piu Piu)
# La Serrania de Jabugo (H-9)
# Asador de Pollos Carreta Al Carbon
# Palacio del Pollo
# Asador de Pollos Cuesta
# Mimbrero Orta
# Mas Ke Pollos
# Bar Las Marismas
# Bar Rincon Portugues
# Freiduria La Ria
# Portichuelo
# La Cantina de Pescadería
# Fonda de María mandao
# Pizza Hut
# Cervecería Bonilla
# Restaurante Fez
# Bratwurst
# Restaurante Chino Zhenbao
# Tapas&Punto Coma
# D'picoteo
# Bodega Madreana
# Casa Pepa Peroles
# La Ibérica Bodeguita
# Pizzería Punto D'Oro
# La Pepa Tapas
# Bar Juan José
# La Luna
# El Rey del Barril
# Nueva Serranía Asador
# Asador de Pollos Hispanidad
# Bar Tapas La Ceutí
# Natural Pizza
# Natural Pizza
# El Pepe
# nan
# nan
# Bar Terraza Áfrika
# nan
# Bar Los Maestres
# Restaurante Kiosco Manolín
# Gran Vía Uno
# La Gamberra
# Cosas buenas
# El Rinconcito
# Bar Hispanidad
# Isla Bacuta
# Assador La Bronce
# nan
# La Tasquita de Candela
# El Faro Terraza Asador
# Comedor Universitario
# Restaurante Jardines del Odiel
# Burguer King
# Monajuana

# %%
restaurants.head()
# Out:
#                         addr:city           addr:street     amenity     brand  \
# element_type osmid
# node         791998072     Huelva    Avda. de Andalucía  restaurant  Pomodoro
#              791998082     Huelva                   NaN  restaurant       NaN
#              791998088     Huelva  Avenida de Palomeque  restaurant       NaN
#              795890820     Huelva     Plaza Huerto Paco  restaurant       NaN
#              1407027584       NaN                   NaN  restaurant       NaN
#
#                                brand:website brand:wikidata  \
# element_type osmid
# node         791998072   https://pomodoro.es     Q115475288
#              791998082                   NaN            NaN
#              791998088                   NaN            NaN
#              795890820                   NaN            NaN
#              1407027584                  NaN            NaN
#
#                                      cuisine                          name  \
# element_type osmid
# node         791998072   italian;pasta;pizza                      Pomodoro
#              791998082              regional  Bar Restaurante La Higuerita
#              791998088              regional     Bar Restaurante Palomeque
#              795890820              regional                  Mesón Madrid
#              1407027584                  NaN                           NaN
#
#                                           geometry addr:country  ...  \
# element_type osmid                                               ...
# node         791998072   POINT (-6.94044 37.26333)          NaN  ...
#              791998082   POINT (-6.93854 37.26197)           ES  ...
#              791998088   POINT (-6.93980 37.26171)           ES  ...
#              795890820   POINT (-6.94315 37.26663)           ES  ...
#              1407027584  POINT (-6.94272 37.28325)          NaN  ...
#
#                         opening_hours website brand:wikipedia loc_name  \
# element_type osmid
# node         791998072            NaN     NaN             NaN      NaN
#              791998082            NaN     NaN             NaN      NaN
#              791998088            NaN     NaN             NaN      NaN
#              795890820            NaN     NaN             NaN      NaN
#              1407027584           NaN     NaN             NaN      NaN
#
#                         contact:instagram email level nodes building  \
# element_type osmid
# node         791998072                NaN   NaN   NaN   NaN      NaN
#              791998082                NaN   NaN   NaN   NaN      NaN
#              791998088                NaN   NaN   NaN   NaN      NaN
#              795890820                NaN   NaN   NaN   NaN      NaN
#              1407027584               NaN   NaN   NaN   NaN      NaN
#
#                         building:levels
# element_type osmid
# node         791998072              NaN
#              791998082              NaN
#              791998088              NaN
#              795890820              NaN
#              1407027584             NaN
#
# [5 rows x 37 columns]

# %%
parks = ox.geometries_from_place(
    Huelva,
    {
        "leisure": "park",
        "landuse": "grass",
    },
)
# Out:
# <ipython-input-17-246991e0f3e8>:1: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   parks = ox.geometries_from_place(

# %%
parks.plot(color='green')
# Out:
# <Axes: >

# %%
import matplotlib
figure, ax = matplotlib.pyplot.subplots(figsize=(12,8))

# Plot street ‘edges’
edges.plot(ax=ax, linewidth=1, edgecolor="black")

# Plot the footprint
#huelva.plot(ax=ax, facecolor="black", alpha=0.6)

# Plot parks
parks.plot(ax=ax, facecolor="green")

# Plot buildings
buildings.plot(ax=ax, facecolor="silver", alpha=0.7)

# Plot restaurants
restaurants.plot(ax=ax, color="yellow", alpha=0.7, markersize=10)
# Out:
# <Axes: >

# %%
edges["highway"].value_counts()
# Out:
# highway
# footway                          16168
# residential                       4170
# tertiary                          2624
# service                           2042
# pedestrian                        1967
# secondary                         1071
# cycleway                           622
# track                              568
# path                               220
# primary                            145
# trunk                              111
# living_street                       99
# motorway_link                       88
# unclassified                        69
# secondary_link                      62
# steps                               52
# motorway                            51
# [pedestrian, footway]               50
# tertiary_link                       40
# [steps, footway]                    35
# [footway, steps]                    21
# trunk_link                          16
# [residential, pedestrian]           12
# [track, residential]                12
# [service, pedestrian]               12
# [residential, footway]              10
# [track, service]                     6
# [service, unclassified]              4
# [residential, steps]                 4
# [service, footway]                   4
# [pedestrian, steps]                  4
# [pedestrian, path]                   2
# [track, unclassified]                2
# [service, living_street]             2
# [path, footway]                      2
# [secondary, trunk]                   2
# [track, path]                        2
# [cycleway, footway]                  2
# [residential, path]                  2
# [pedestrian, living_street]          2
# bus_stop                             2
# [service, path]                      2
# [service, residential]               1
# [footway, residential, steps]        1
# [residential, service]               1
# [steps, residential, footway]        1
# Name: count, dtype: int64

# %%
# Transform the graph to UTM
graph = osmnx.project_graph(graph)

# Extract reprojected nodes and edges
nodes, edges = osmnx.graph_to_gdfs(graph)

nodes.crs
# Out:
# <Projected CRS: +proj=utm +zone=29 +ellps=WGS84 +datum=WGS84 +unit ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: UTM zone 29N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Calculate network statistics
osmnx.basic_stats(graph)
# Out:
# {'n': 10703,
#  'm': 30385,
#  'k_avg': 5.677847332523592,
#  'edge_length_total': 1703790.1330000116,
#  'edge_length_avg': 56.07339585321743,
#  'streets_per_node_avg': 3.1871437914603384,
#  'streets_per_node_counts': {0: 0,
#   1: 585,
#   2: 31,
#   3: 6970,
#   4: 3040,
#   5: 68,
#   6: 8,
#   7: 1},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.05465757264318415,
#   2: 0.00289638419134822,
#   3: 0.6512192843128095,
#   4: 0.2840325142483416,
#   5: 0.006353358871344483,
#   6: 0.0007474539848640568,
#   7: 9.34317481080071e-05},
#  'intersection_count': 10118,
#  'street_length_total': 969059.148000003,
#  'street_segment_count': 17052,
#  'street_length_avg': 56.82964743138652,
#  'circuity_avg': 1.0997667401193159,
#  'self_loop_proportion': 0.002228477597935726}

# %%
origin = (
    osmnx.geocode_to_gdf("Plaza de la Merced, Huelva")  # fetch geolocation
    .to_crs(edges.crs)  # transform to UTM
    .at[0, "geometry"]  # pick geometry of first row
    .centroid  # use the centre point
)

destination = (
    osmnx.geocode_to_gdf("Casa Colón, Huelva")
    .to_crs(edges.crs)
    .at[0, "geometry"]
    .centroid
)

# %%
origin_node_id = osmnx.nearest_nodes(graph, origin.x, origin.y)
origin_node_id
# Out:
# 4796492543

# %%
destination_node_id = osmnx.nearest_nodes(graph, destination.x, destination.y)
destination_node_id
# Out:
# 3677640753

# %%
# Find the shortest path between origin and destination
route = osmnx.shortest_path(graph, origin_node_id, destination_node_id)
route
# Out:
# [4796492543,
#  4796492544,
#  270190710,
#  270190712,
#  270190701,
#  599668085,
#  8417892582,
#  8417892581,
#  8219823345,
#  8417892589,
#  8219823333,
#  12022515600,
#  8417892595,
#  8417892594,
#  8417892591,
#  8417892590,
#  8219846337,
#  8219846326,
#  8219846325,
#  8219846324,
#  4795379700,
#  798575000,
#  8219835013,
#  965873273,
#  798574980,
#  1152780507,
#  1152780469,
#  1152780482,
#  3677640753]

# %%
# Plot the shortest path
fig, ax = osmnx.plot_graph_route(graph, route)

# %%
# Get the nodes along the shortest path
route_nodes = nodes.loc[route]
route_nodes
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                      y         x  ref          highway  street_count  \
# osmid
# 4796492543   37.262628 -6.951985  NaN              NaN             3
# 4796492544   37.262088 -6.952193  NaN              NaN             4
# 270190710    37.262013 -6.951561  NaN              NaN             4
# 270190712    37.261732 -6.950403  NaN              NaN             3
# 270190701    37.261730 -6.950106  NaN              NaN             3
# 599668085    37.260488 -6.949730  NaN              NaN             3
# 8417892582   37.260160 -6.950191  NaN         crossing             4
# 8417892581   37.260156 -6.950156  NaN              NaN             3
# 8219823345   37.260144 -6.950155  NaN              NaN             3
# 8417892589   37.260118 -6.950157  NaN         crossing             4
# 8219823333   37.260081 -6.950160  NaN              NaN             3
# 12022515600  37.259990 -6.950188  NaN              NaN             3
# 8417892595   37.259869 -6.950144  NaN              NaN             3
# 8417892594   37.259836 -6.950153  NaN         crossing             4
# 8417892591   37.259767 -6.949736  NaN         crossing             4
# 8417892590   37.259734 -6.949745  NaN              NaN             3
# 8219846337   37.258701 -6.950330  NaN              NaN             3
# 8219846326   37.258678 -6.950299  NaN         crossing             4
# 8219846325   37.258635 -6.950245  NaN              NaN             3
# 8219846324   37.258580 -6.950268  NaN         crossing             4
# 4795379700   37.258580 -6.950221  NaN              NaN             3
# 798575000    37.258342 -6.950172  NaN  traffic_signals             3
# 8219835013   37.258317 -6.950174  NaN         crossing             4
# 965873273    37.258230 -6.950178  NaN              NaN             3
# 798574980    37.257156 -6.949513  NaN              NaN             3
# 1152780507   37.256792 -6.948990  NaN              NaN             4
# 1152780469   37.256188 -6.948060  NaN              NaN             4
# 1152780482   37.255963 -6.947470  NaN              NaN             3
# 3677640753   37.255057 -6.947185  NaN              NaN             3
#
#                               geometry
# osmid
# 4796492543   POINT (-6.95198 37.26263)
# 4796492544   POINT (-6.95219 37.26209)
# 270190710    POINT (-6.95156 37.26201)
# 270190712    POINT (-6.95040 37.26173)
# 270190701    POINT (-6.95011 37.26173)
# 599668085    POINT (-6.94973 37.26049)
# 8417892582   POINT (-6.95019 37.26016)
# 8417892581   POINT (-6.95016 37.26016)
# 8219823345   POINT (-6.95015 37.26014)
# 8417892589   POINT (-6.95016 37.26012)
# 8219823333   POINT (-6.95016 37.26008)
# 12022515600  POINT (-6.95019 37.25999)
# 8417892595   POINT (-6.95014 37.25987)
# 8417892594   POINT (-6.95015 37.25984)
# 8417892591   POINT (-6.94974 37.25977)
# 8417892590   POINT (-6.94974 37.25973)
# 8219846337   POINT (-6.95033 37.25870)
# 8219846326   POINT (-6.95030 37.25868)
# 8219846325   POINT (-6.95025 37.25863)
# 8219846324   POINT (-6.95027 37.25858)
# 4795379700   POINT (-6.95022 37.25858)
# 798575000    POINT (-6.95017 37.25834)
# 8219835013   POINT (-6.95017 37.25832)
# 965873273    POINT (-6.95018 37.25823)
# 798574980    POINT (-6.94951 37.25716)
# 1152780507   POINT (-6.94899 37.25679)
# 1152780469   POINT (-6.94806 37.25619)
# 1152780482   POINT (-6.94747 37.25596)
# 3677640753   POINT (-6.94718 37.25506)

# %%
import shapely.geometry

# Create a geometry for the shortest path
route_line = shapely.geometry.LineString(
    list(route_nodes.geometry.values)
)
route_line
# Out:
# <LINESTRING (-6.952 37.263, -6.952 37.262, -6.952 37.262, -6.95 37.262, -6.9...>

# %%
import geopandas

route_geom = geopandas.GeoDataFrame(
    {
        "geometry": [route_line],
        "osm_nodes": [route],
    },
    crs=edges.crs
)

# Calculate the route length
route_geom["length_m"] = route_geom.length

route_geom.head()
# Out:
# <ipython-input-34-2fecdc113c33>:12: UserWarning: Geometry is in a geographic CRS. Results from 'length' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   route_geom["length_m"] = route_geom.length
#                                             geometry  \
# 0  LINESTRING (-6.95198 37.26263, -6.95219 37.262...
#
#                                            osm_nodes  length_m
# 0  [4796492543, 4796492544, 270190710, 270190712,...  0.011739

# %%
buildings.head()
# Out:
#                                           geometry addr:city addr:housenumber  \
# element_type osmid
# node         1542062287  POINT (-6.95245 37.25614)       NaN              NaN
#              4991109060  POINT (-6.95503 37.25656)       NaN              NaN
#              5808932168  POINT (-6.94935 37.24168)    Huelva               21
#              7997720516  POINT (-6.94872 37.25905)       NaN              NaN
#              8090578692  POINT (-7.00034 37.25509)       NaN              NaN
#
#                         addr:postcode           addr:street    amenity  fee  \
# element_type osmid
# node         1542062287           NaN                   NaN        NaN  NaN
#              4991109060           NaN                   NaN     clinic  NaN
#              5808932168         21005  Calle Joaquín Turina  recycling  NaN
#              7997720516           NaN                   NaN    parking  NaN
#              8090578692           NaN                   NaN        NaN  NaN
#
#                                                                       name  \
# element_type osmid
# node         1542062287  Inspección Provincial de Trabajo y Seguridad S...
#              4991109060  Delegación Provincial de Turismo, Comercio y D...
#              5808932168                             Punto limpio de Huelva
#              7997720516                                                NaN
#              8090578692                                           La Choza
#
#                         building       government  ...  \
# element_type osmid                                 ...
# node         1542062287      yes  social_security  ...
#              4991109060    civic              NaN  ...
#              5808932168      yes              NaN  ...
#              7997720516      yes              NaN  ...
#              8090578692      yes              NaN  ...
#
#                         seamark:light:reference  \
# element_type osmid
# node         1542062287                     NaN
#              4991109060                     NaN
#              5808932168                     NaN
#              7997720516                     NaN
#              8090578692                     NaN
#
#                         seamark:radar_transponder:category  \
# element_type osmid
# node         1542062287                                NaN
#              4991109060                                NaN
#              5808932168                                NaN
#              7997720516                                NaN
#              8090578692                                NaN
#
#                         seamark:radar_transponder:group  \
# element_type osmid
# node         1542062287                             NaN
#              4991109060                             NaN
#              5808932168                             NaN
#              7997720516                             NaN
#              8090578692                             NaN
#
#                         seamark:radar_transponder:period seamark:type ways  \
# element_type osmid
# node         1542062287                              NaN          NaN  NaN
#              4991109060                              NaN          NaN  NaN
#              5808932168                              NaN          NaN  NaN
#              7997720516                              NaN          NaN  NaN
#              8090578692                              NaN          NaN  NaN
#
#                          bus public_transport type operator:website
# element_type osmid
# node         1542062287  NaN              NaN  NaN              NaN
#              4991109060  NaN              NaN  NaN              NaN
#              5808932168  NaN              NaN  NaN              NaN
#              7997720516  NaN              NaN  NaN              NaN
#              8090578692  NaN              NaN  NaN              NaN
#
# [5 rows x 118 columns]

# %%
import contextily
import matplotlib.pyplot

fig, ax = matplotlib.pyplot.subplots(figsize=(15,10))

# Plot edges and nodes
edges.plot(ax=ax, linewidth=0.75, color='gray')
nodes.plot(ax=ax, markersize=2, color='gray')

# Add buildings
#ax = buildings.plot(ax=ax, facecolor='lightgray', alpha=0.7)

# Add the route
ax = route_geom.plot(ax=ax, linewidth=2, linestyle='--', color='red')


# Add basemap
contextily.add_basemap(ax, crs=buildings.crs, source=contextily.providers.CartoDB.Positron)
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDrive2ImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _PyDriveImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _GenerativeAIImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _OpenCVImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: APICoreClientInfoImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _BokehImportHook.find_spec() not found; falling back to find_module()
# <frozen importlib._bootstrap>:914: ImportWarning: _AltairImportHook.find_spec() not found; falling back to find_module()
